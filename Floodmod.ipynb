# %%
# Basic libraries
import pandas as pd
import numpy as np

# Visualization (optional but useful)
import matplotlib.pyplot as plt
import seaborn as sns

# ML libraries
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
data = pd.read_csv("flood.csv")

# %%
data.head()
# Out:
#    MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                 3                   8                6              6
# 1                 8                   4                5              7
# 2                 3                  10                4              1
# 3                 4                   4                2              7
# 4                 3                   7                5              2
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             4              4            6          2                      3
# 1             7              9            1          5                      5
# 2             7              5            4          7                      4
# 3             3              4            1          4                      6
# 4             5              8            5          2                      7
#
#    Encroachments  ...  DrainageSystems  CoastalVulnerability  Landslides  \
# 0              2  ...               10                     7           4
# 1              4  ...                9                     2           6
# 2              9  ...                7                     4           4
# 3              4  ...                4                     2           6
# 4              5  ...                7                     6           5
#
#    Watersheds  DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 0           2                            3                4            3
# 1           2                            1                1            9
# 2           8                            6                1            8
# 3           6                            8                8            6
# 4           3                            3                4            4
#
#    InadequatePlanning  PoliticalFactors  FloodProbability
# 0                   2                 6             0.450
# 1                   1                 3             0.475
# 2                   3                 6             0.515
# 3                   6                10             0.520
# 4                   3                 4             0.475
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   MonsoonIntensity                 50000 non-null  int64
#  1   TopographyDrainage               50000 non-null  int64
#  2   RiverManagement                  50000 non-null  int64
#  3   Deforestation                    50000 non-null  int64
#  4   Urbanization                     50000 non-null  int64
#  5   ClimateChange                    50000 non-null  int64
#  6   DamsQuality                      50000 non-null  int64
#  7   Siltation                        50000 non-null  int64
#  8   AgriculturalPractices            50000 non-null  int64
#  9   Encroachments                    50000 non-null  int64
#  10  IneffectiveDisasterPreparedness  50000 non-null  int64
#  11  DrainageSystems                  50000 non-null  int64
#  12  CoastalVulnerability             50000 non-null  int64
#  13  Landslides                       50000 non-null  int64
#  14  Watersheds                       50000 non-null  int64
#  15  DeterioratingInfrastructure      50000 non-null  int64
#  16  PopulationScore                  50000 non-null  int64
#  17  WetlandLoss                      50000 non-null  int64
#  18  InadequatePlanning               50000 non-null  int64
#  19  PoliticalFactors                 50000 non-null  int64
#  20  FloodProbability                 50000 non-null  float64
# dtypes: float64(1), int64(20)
# memory usage: 8.0 MB

# %%
data.columns
# Out:
# Index(['MonsoonIntensity', 'TopographyDrainage', 'RiverManagement',
#        'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality',
#        'Siltation', 'AgriculturalPractices', 'Encroachments',
#        'IneffectiveDisasterPreparedness', 'DrainageSystems',
#        'CoastalVulnerability', 'Landslides', 'Watersheds',
#        'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss',
#        'InadequatePlanning', 'PoliticalFactors', 'FloodProbability'],
#       dtype='str')

# %%
X = data.drop('FloodProbability', axis=1)
y = data['FloodProbability']

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
from sklearn.metrics import mean_squared_error

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print("MSE:", mse)
# Out:
# MSE: 0.0006810774227500004

# %%
sample = X.iloc[0]  # take one real row

prediction = model.predict([sample])

print("Predicted Flood Probability:", prediction[0])
# Out:
# Predicted Flood Probability: 0.4600000000000003
# /Users/suryaveersingh/Documents/Disaster/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
import joblib

joblib.dump(model, "flood_model.pkl")
# Out:
# ['flood_model.pkl']

# %%
y.head()
# Out:
# 0    0.450
# 1    0.475
# 2    0.515
# 3    0.520
# 4    0.475
# Name: FloodProbability, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MSE:", mse)
print("R2 Score:", r2)
# Out:
# MSE: 0.0006810774227500004
# R2 Score: 0.7325329165540964

# %%
import pandas as pd

importance = model.feature_importances_
features = X.columns

feature_importance = pd.DataFrame({
    'Feature': features,
    'Importance': importance
}).sort_values(by='Importance', ascending=False)

feature_importance
# Out:
#                             Feature  Importance
# 1                TopographyDrainage    0.053255
# 10  IneffectiveDisasterPreparedness    0.052393
# 2                   RiverManagement    0.051753
# 6                       DamsQuality    0.051608
# 19                 PoliticalFactors    0.051168
# 15      DeterioratingInfrastructure    0.050901
# 0                  MonsoonIntensity    0.050490
# 14                       Watersheds    0.050322
# 3                     Deforestation    0.050228
# 7                         Siltation    0.050027
# 16                  PopulationScore    0.049946
# 8             AgriculturalPractices    0.049835
# 5                     ClimateChange    0.049573
# 13                       Landslides    0.049428
# 17                      WetlandLoss    0.049360
# 4                      Urbanization    0.048984
# 18               InadequatePlanning    0.048410
# 12             CoastalVulnerability    0.047637
# 11                  DrainageSystems    0.047409
# 9                     Encroachments    0.047273

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.barh(feature_importance['Feature'], feature_importance['Importance'])
plt.gca().invert_yaxis()
plt.title("Feature Importance")
plt.show()

# %%
def flood_alert(prob):
    if prob < 0.4:
        return "✅ Low Risk"
    elif prob < 0.7:
        return "⚠️ Medium Risk"
    else:
        return "🚨 High Risk"


sample = X.iloc[0]
prediction = model.predict([sample])[0]

print("Flood Probability:", prediction)
print("Alert:", flood_alert(prediction))
# Out:
# Flood Probability: 0.4600000000000003
# Alert: ⚠️ Medium Risk
# /Users/suryaveersingh/Documents/Disaster/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
import joblib

joblib.dump(model, "flood_model.pkl")
joblib.dump(X.columns.tolist(), "model_features.pkl")
# Out:
# ['model_features.pkl']
